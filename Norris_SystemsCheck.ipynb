# %% [markdown]
# # Example Test

# %% [markdown]
# this is just text

# %% [markdown]
# This is a sample list
#
# 1. one
# 2. two
# 3. three
#
# - one
# - two
# - three

# %% [markdown]
# ## This is a subtitle

# %% [markdown]
# ### This is a sub sub heading

# %% [markdown]
# # Systems Test

# %% [markdown]
# ## Alaina Norris

# %% [markdown]
# ### 08/20/2025

# %% [markdown]
# In this class I want to learn how to use __Python__. I hope that learning this will help me build _skills_ for my major.

# %% [markdown]
# I want to gain an intermediate understanding of Python and get take aways from this class to:
# 1. Have something to add to my resume
# 2. Learn a new skill that will benefit me in my Business Analytics Major
# 3. Get a good grade in this Data in Emerging Media and Technology Course.

# %% [markdown]
# ![Python-logo.jpg](attachment:c6615552-127e-4b2d-9642-8067e2bc3dd2.jpg)
